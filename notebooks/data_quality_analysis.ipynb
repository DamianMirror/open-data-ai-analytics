# %% [markdown]
# # Дослідження датасету
# Основні прогнозні показники економічного і соціального розвитку України на 2020–2021 роки

# %%
import sys
sys.path.append('..')

from src.data_load import download, load

download()
df = load()
# Out:
# [skip] Файл вже існує: D:\code\AI\open-data-ai-analytics\data\raw\nabir-16-2020-2021.csv
# [ok] Завантажено 17 рядків, 8 колонок (encoding=cp1251)

# %%
df.head(10)
# Out:
#    Unnamed: 0                                           Показник  \
# 0           1  Валовий внутрішній продукт номінальний, млрд. ...
# 1           2  Валовий внутрішній продукт, відсотків до попер...
# 2           3  Індекс споживчих цін у середньому до попереднь...
# 3           4  Індекс споживчих цін грудень до грудня поперед...
# 4           5  Індекс цін виробників промислової продукції (г...
# 5           6    Прибуток прибуткових підприємств, млрд. гривень
# 6           7  Фонд оплати праці найманих працівників і грошо...
# 7           8  Середньомісячна заробітна плата працівників, б...
# 8           9  Середньомісячна заробітна плата працівників, б...
# 9          10  Кількість зайнятих економічною діяльністю у ві...
#
#   Прогноз 2020 сценарій 1 Прогноз 2020 сценарій 2 Прогноз 2020 сценарій 3  \
# 0                4 450,90                   4 609                4 502,60
# 1                   103,8                     105                   101,6
# 2                   106,7                   107,9                   109,9
# 3                   105,6                     107                   108,6
# 4                   108,2                     109                   110,9
# 5                   999,5                  1055,5                   950,3
# 6                  1290,8                  1393,7                  1267,1
# 7                  11 451                  12 137                  11 359
# 8                     106                   106,2                   102,2
# 9                   16,46                   16,55                   16,38
#
#   Прогноз 2021 сценарій 1 Прогноз 2021 сценарій 2 Прогноз 2021 сценарій 3
# 0                4 972,60                5 223,90                5 045,30
# 1                   104,1                   105,4                   102,1
# 2                   105,5                   106,1                   107,8
# 3                     105                   105,2                   106,7
# 4                   105,9                   106,5                   108,2
# 5                  1128,4                  1212,6                  1069,9
# 6                  1444,5                  1582,6                  1402,3
# 7                  12 835                  13 766                  12 663
# 8                   106,2                   106,9                   103,4
# 9                   16,52                    16,7                   16,41

# %%
print('Форма:', df.shape)
print('Колонки:', df.columns.tolist())
# Out:
# Форма: (17, 8)
# Колонки: ['Unnamed: 0', 'Показник', 'Прогноз 2020 сценарій 1', 'Прогноз 2020 сценарій 2', 'Прогноз 2020 сценарій 3', 'Прогноз 2021 сценарій 1', 'Прогноз 2021 сценарій 2', 'Прогноз 2021 сценарій 3']

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# Показник                   object
# Прогноз 2020 сценарій 1    object
# Прогноз 2020 сценарій 2    object
# Прогноз 2020 сценарій 3    object
# Прогноз 2021 сценарій 1    object
# Прогноз 2021 сценарій 2    object
# Прогноз 2021 сценарій 3    object
# dtype: object

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0                                           Показник  \
# count    17.000000                                                 17
# unique         NaN                                                 17
# top            NaN  Валовий внутрішній продукт номінальний, млрд. ...
# freq           NaN                                                  1
# mean      9.000000                                                NaN
# std       5.049752                                                NaN
# min       1.000000                                                NaN
# 25%       5.000000                                                NaN
# 50%       9.000000                                                NaN
# 75%      13.000000                                                NaN
# max      17.000000                                                NaN
#
#        Прогноз 2020 сценарій 1 Прогноз 2020 сценарій 2  \
# count                       17                      17
# unique                      17                      17
# top                   4 450,90                   4 609
# freq                         1                       1
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#        Прогноз 2020 сценарій 3 Прогноз 2021 сценарій 1  \
# count                       17                      17
# unique                      17                      17
# top                   4 502,60                4 972,60
# freq                         1                       1
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#        Прогноз 2021 сценарій 2 Прогноз 2021 сценарій 3
# count                       17                      17
# unique                      17                      17
# top                   5 223,90                5 045,30
# freq                         1                       1
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Показник                   0
# Прогноз 2020 сценарій 1    0
# Прогноз 2020 сценарій 2    0
# Прогноз 2020 сценарій 3    0
# Прогноз 2021 сценарій 1    0
# Прогноз 2021 сценарій 2    0
# Прогноз 2021 сценарій 3    0
# dtype: int64
